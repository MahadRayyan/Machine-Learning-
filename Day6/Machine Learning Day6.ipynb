# %% [markdown]
# # L1 Lasso Regularization
#
# it is a feature selection technique using shrinkage method
# it add penalty to loss function because of Coefficients are moved toward 0 or something make zero as well

# %% [markdown]
# # L2 Ridge Regulation
#
# it help to reduce model complexity and prevent overfitting
# it add penalty to loss function because of Coefficients are moved toward 0

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression ,Lasso , Ridge

# %%
dataset=pd.read_csv("houseprice_200.csv")
df.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0         4       1.66         2941     42034     3.0           0     1
# 1         5       2.67         3859     10702     1.0           0     2
# 2         3       2.21         3759      2384     1.0           0     1
# 3         5       1.19         3065      2404     3.0           0     0
# 4         5       1.76         3279     42943     3.0           0     2
#
#    condition  sqft_above  sqft_basement  yr_built  yr_renovated   price
# 0          2        3709            588      1969             0  647598
# 1          4        2548           1182      1940             0  831371
# 2          4         958            488      2002             0  747966
# 3          5        2777            970      1967             0  651649
# 4          5        1756           1347      1912             0  606557

# %%
plt.figure(figsize=(10,5))
sns.heatmap(data=dataset.corr(),annot=True)
plt.show()

# %%
x=dataset.iloc[:,:-1]
y=dataset["price"]

# %%
ss=StandardScaler()
ss.fit(x)
# Out:
# StandardScaler()

# %%
x=pd.DataFrame(ss.transform(x),columns=x.columns)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# # Linear Model

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)
# Out:
# 0.9429253124989195

# %%
plt.figure(figsize=(15,5))
plt.bar(x.columns,lr.coef_)
plt.show()

# %% [markdown]
# # Lasso Model

# %%
la=Lasso(alpha=10)
la.fit(x_train,y_train)
# Out:
# Lasso(alpha=10)

# %%
la.score(x_test,y_test)
# Out:
# 0.9429379058574779

# %%
plt.figure(figsize=(15,5))
plt.bar(x.columns,la.coef_)
plt.show()

# %% [markdown]
# # Ridge Model

# %%
ri= Ridge()
ri.fit(x_train,y_train)
# Out:
# Ridge()

# %%
ri.score(x_test,y_test)
# Out:
# 0.9424076481365529

# %%
plt.figure(figsize=(15,5))
plt.bar(x.columns,ri.coef_)
plt.show()
